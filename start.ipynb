# %% [markdown]
# <a href="https://colab.research.google.com/github/porwoj/password_genrator/blob/main/start.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("halo colab")
# Out:
# halo colab
